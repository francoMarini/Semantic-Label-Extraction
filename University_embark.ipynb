# %% [markdown]
# # University_embark

# %% [markdown]
# Colonne significative all'interno della tabella:
# *	iiriirrliiirliiii (Nome dell’Università)
# *	iiriirrliiirliirilli (Indirizzo)
# *	iiriirrliiirliirillri (Città)
# *	iiriirrliiirliirrrlliirrrli (Titolo di studio)

# %%
#Questo parametro indica il numero di valori che devo analizzare per stabilire l'etichetta corretta.
RECORDS_NUMBER= 100

# %% [markdown]
# ## Librerie

# %%
import requests
from requests.exceptions import ConnectionError
from transformers import pipeline

from transformers import logging as hf_logging
hf_logging.set_verbosity_error()

# %% [markdown]
# ## Labels candidate

# %%
labels=['name of school', 'address', 'city', 'student degree']

# %% [markdown]
# # Label: Name of School

# %%
url='http://localhost:8123/?query=SELECT top 100 iiriirrliiirliiii FROM extracted_data.f57978e4a01748598d876bdcc0ba1d14'

try:
    r = requests.get(url)
except ConnectionError:
        print("Il collegamento al database non è attivo.")

        
#L'utf-8-sig è una variante Python di UTF-8 che ci permette di eliminare, se presenti, eventuali carattere UTF-8 BOM.
values= r.content.decode('utf-8-sig')


#Controllo i parametri inseriti dall'utente
if (values[6:8]=='60'):
    print("ATTENZIONE! La tabella indicata non esiste.")
elif (values[6:8]=='47'):
    print("ATTENZIONE! La colonna indicata non esiste.")
else:
    print("I dati sono stati caricati correttamente.")
# Out:
# I dati sono stati caricati correttamente.

# %%
#Preproccesing
values = values.replace("\ufeff", "")
values = values.replace("\\", " ")
values=values.split('\n')
values= list(filter(lambda a: a!= '', values))
items_number= len(values)
values
# Out:
# ['Abraham Baldwin Agricultural College',
#  'Academy College',
#  'Academy of Healing Arts, Massage,',
#  'Academy of Medical Arts and Business',
#  'Academy Pacific Business and Travel College',
#  'Adelphi University',
#  'Adrian College',
#  'Agnes Scott College',
#  'AIB College of Business',
#  'Aiken Technical College',
#  'AIMS Academy (Dallas)',
#  'AIMS Academy (Grand Prairie)',
#  'Aims Community College',
#  'Akron Institute',
#  'Akron Machining Institute',
#  'Alabama Southern Community College (Monroeville)',
#  'Alabama Southern Community College (Thomasville)',
#  'Alabama State University',
#  'Albany State University',
#  'Albert A. List College of Jewish Studies at JTS',
#  'Albertus Magnus College',
#  'Alderson-Broaddus College',
#  'Alexandria Technical College',
#  'Alfred University Undergraduate Application',
#  'All-State Career School (Maryland)',
#  'Allan Hancock College',
#  'Allegany College - Bedford County Campus',
#  'Allegany College - Somerset Campus',
#  'Allen County Community College',
#  'Alma College',
#  'Altamaha Technical Institute (Jesup)',
#  'American Academy of Dramatic Arts West',
#  'American Ballet Center/Joffrey Ballet School',
#  'American Commercial College (Lubbock)',
#  'American Health Science University',
#  'American Indian College of the Assemblies of God, Inc.',
#  'American Institute of Applied Science',
#  'American Institute of Health Technology, Inc.',
#  'American Institute of Technology',
#  'American International College',
#  'American Jewish University',
#  'American School of Business (Louisiana)',
#  'American Trans Air Aviation',
#  'Ancilla College',
#  'Anderson College',
#  'Anderson University',
#  'Andover College',
#  'Andrews University',
#  'Angelina College',
#  'Anoka-Hennepin Technical College',
#  'Anoka-Ramsey Community College',
#  'Antonelli College (Jackson)',
#  'Antonelli College (Ohio)',
#  'Antonelli Institute',
#  'Apex Technical School',
#  'Apollo College of Medical-Dental Careers',
#  'Appalachian State University',
#  'Applied Career Training, Inc.',
#  'Arapahoe Community College',
#  'Arcadia University',
#  'Arizona Institute of Business and Technology - Mesa',
#  'Arizona Institute of Business and Technology - West Valley',
#  'Arizona State University East',
#  'Arizona State University West',
#  'Arizona Western College',
#  'Arkansas State University',
#  'Arkansas State University - Beebe',
#  'Arkansas State University - Newport Campus',
#  'Art Institute of Charlotte',
#  'Art Institute of Colorado',
#  'Art Institute of Southern California',
#  'Asbury College',
#  'Ashland Community College',
#  'Ashland Technical College',
#  'Asnuntuck Community College',
#  'ASU MBA',
#  'Athens Area Technical Institute',
#  'ATI - Career Training Center (Hurst)',
#  'ATI - Health Education Center',
#  'Atlanta Institute of Music',
#  'Atlanta School of Massage',
#  'Atlantic County Vocational School',
#  'Atlantic Technical Center (Coconut Creek)',
#  'Auburn University',
#  'Auburn University-Montgomery',
#  'Audrey Cohen College',
#  'Augsburg College',
#  'Augustana College (IL)',
#  'Austin College',
#  'Austin Community College',
#  'Automotive Training Center',
#  'Avila College International Programs',
#  'Avila University',
#  'Azusa Pacific University',
#  'Babson College',
#  'Babson College FW Olin Graduate School of Business',
#  'Bacone College',
#  'Bakersfield College',
#  'Baldwin-Wallace College',
#  'Ball State University']

# %%
#Struttura: dictionary[label] -> [89%, 93%, 97%, 32%, 99% , ...]
dictionary={}

#Sruttura ausiliaria: permette di stabilire il numero di volte in cui ciascuna etichetta è stata predetta
occorrenze={}


#Crea una lista vuota per ciascuna label
for label in labels:
    dictionary[label]=[]
    occorrenze[label]=0
    

classifier = pipeline("zero-shot-classification")
    
labels_number= len(labels)

#Vengono effettuate le previsioni attraverso il modello.
#Le previsioni vengono memorizzate nel dizionario.
for i in range(RECORDS_NUMBER):
    text = values[i]
    result=classifier(text, labels)
    occorrenze[result['labels'][0]]+=1
    for y in range(labels_number):
        label= result['labels'][y]
        score= result['scores'][y]
        dictionary[label].append(score)    
        
        
risultati={}
for label in labels:
    risultati[label]= sum(dictionary[label])/items_number

max_score= 0

for label, score in risultati.items():  
    if score > max_score:
        label_predict=label
        max_score=score

print("Etichetta predetta: %s \n\n\n" % label_predict)
print("Grado di affidabilità: %.3f\n" % max_score)
print("%d/%d -> Questa etichetta è stata predetta %d volte su %d." 
      % (occorrenze[label_predict], items_number, occorrenze[label_predict], items_number))
# Out:
# Etichetta predetta: name of school
#
#
#
# Grado di affidabilità: 0.728
#
# 92/100 -> Questa etichetta è stata predetta 92 volte su 100.

# %% [markdown]
# # Label: Address

# %%
url='http://localhost:8123/?query=SELECT top 100 iiriirrliiirliirilli FROM extracted_data.f57978e4a01748598d876bdcc0ba1d14'

try:
    r = requests.get(url)
except ConnectionError:
        print("Il collegamento al database non è attivo.")

        
#L'utf-8-sig è una variante Python di UTF-8 che ci permette di eliminare, se presenti, eventuali carattere UTF-8 BOM.
values= r.content.decode('utf-8-sig')


#Controllo i parametri inseriti dall'utente
if (values[6:8]=='60'):
    print("ATTENZIONE! La tabella indicata non esiste.")
elif (values[6:8]=='47'):
    print("ATTENZIONE! La colonna indicata non esiste.")
else:
    print("I dati sono stati caricati correttamente.")
# Out:
# I dati sono stati caricati correttamente.

# %%
#Preproccesing
values = values.replace("\ufeff", "")
values = values.replace("\\", " ")
values=values.split('\n')
values= list(filter(lambda a: a!= '', values))
items_number= len(values)
values
# Out:
# ['ABAC Station, Box 37',
#  '3050 Metro Drive, Suite 200',
#  '3141 South Military Trail',
#  '2301 Academy Drive',
#  '1777 North Vine Street',
#  'Levermore Hall 114',
#  '110 South Madison Street',
#  '141 East College Avenue',
#  '2500 Fleur Drive',
#  'P.O. Drawer 696',
#  '3300 Oaklawn, Suite 100',
#  '1106 North Highway 360, Box 305',
#  '5401 West 20th Street',
#  '1625 Portage Trail',
#  '2959 Barber Road',
#  'P.O. Box 2000',
#  'Highway 43 South',
#  '915 South Jackson Street',
#  '504 College Drive',
#  '3080 Broadway',
#  '700 Prospect Street',
#  'P.O. Box 2003',
#  '1601 Jefferson Street',
#  'Alumni Hall',
#  '2200 Broening Highway, Suite 160',
#  '800 South College Drive',
#  '18 North River Lane',
#  'RD 5, Box 24C',
#  '1801 North Cottonwood',
#  '614 West Superior Street',
#  '1777 West Cherry Street',
#  '1336 North LaBrea Avenue',
#  '434 Avenue of the Americas',
#  '2007 34th Street',
#  '1010 South Joliet, Suite 107',
#  'Phoenix, AZ 85021',
#  '100 Hunter Place',
#  '1200 North Liberty Drive',
#  '440 South 54th Avenue',
#  '1000 State Street',
#  '15600 Mulholland Drive',
#  '702 Professional Drive North',
#  '7251 West McCarty Street',
#  'P.O. Box 1',
#  '316 Boulevard',
#  '1100 East Fifth Street',
#  '901 Washington Avenue',
#  'Office of Admissions',
#  'P.O. Box 1768',
#  '1355 West Highway 10',
#  '11200 Mississippi Boulevard, NW',
#  '2323 Lakeland Drive',
#  '124 East Seventh Street',
#  '300 Montgomery Avenue',
#  '635 Avenue of the Americas',
#  '2600 S.E. 98th Street',
#  'Office of Admissions',
#  '1100 Wilson Boulevard, Mall Level',
#  '2500 West College Avenue',
#  '450 South Easton Road',
#  '925 South Gilbert Road, Suite 201',
#  '4136 North 75th Avenue, Suite 211',
#  'AZ State University',
#  'PO Box 37100',
#  'P.O. Box 929',
#  'PO Box 1630',
#  'P.O. Box 1000',
#  '7648 Victory Boulevard',
#  '2110 Water Ridge Parkway  nThree Lake Pointe Plaza',
#  '1200 Lincoln St.',
#  '2222 laguna canyon road',
#  '1 Macklem Drive',
#  '1400 College Drive',
#  '4818 Roberts Drive',
#  '170 Elm Street',
#  'P.O. Box 874906',
#  '800 U.S. Highway 29 North',
#  '235 Northeast Loop 820, Suite 110',
#  '1395 N.W. 167th Street, Suite 200',
#  '5985 Financial Drive, Suite 200',
#  '2300 Peachford Road, Suite 3200',
#  '5080 Atlantic Avenue',
#  '4700 Coconut Creek Parkway',
#  '108 Mary Martin Hall',
#  'P.O. Box 244023',
#  '75 Varick Street',
#  '2211 Riverside Avenue South',
#  '639 38th Street',
#  '900 North Grand Ave, Suite 6N',
#  '5930 Middle Fiskville Road',
#  '114 Pickering Way',
#  '11901 Wornall Road',
#  '11901 Wornall Road',
#  '901 East Alosta Avenue',
#  'Lunder Hall',
#  'Olin Hall',
#  '2299 Old Bacone Road',
#  '1801 Panorama Drive',
#  '275 Eastland Rd',
#  'Office of Admissions']

# %%
#Struttura: dictionary[label] -> [89%, 93%, 97%, 32%, 99% , ...]
dictionary={}

#Sruttura ausiliaria: permette di stabilire il numero di volte in cui ciascuna etichetta è stata predetta
occorrenze={}


#Crea una lista vuota per ciascuna label
for label in labels:
    dictionary[label]=[]
    occorrenze[label]=0
    

classifier = pipeline("zero-shot-classification")
    
labels_number= len(labels)

#Vengono effettuate le previsioni attraverso il modello.
#Le previsioni vengono memorizzate nel dizionario.
for i in range(RECORDS_NUMBER):
    text = values[i]
    result=classifier(text, labels)
    occorrenze[result['labels'][0]]+=1
    for y in range(labels_number):
        label= result['labels'][y]
        score= result['scores'][y]
        dictionary[label].append(score)    
        
        
risultati={}
for label in labels:
    risultati[label]= sum(dictionary[label])/items_number

max_score= 0

for label, score in risultati.items():  
    if score > max_score:
        label_predict=label
        max_score=score

print("Etichetta predetta: %s \n\n\n" % label_predict)
print("Grado di affidabilità: %.3f\n" % max_score)
print("%d/%d -> Questa etichetta è stata predetta %d volte su %d." 
      % (occorrenze[label_predict], items_number, occorrenze[label_predict], items_number))
# Out:
# Etichetta predetta: address
#
#
#
# Grado di affidabilità: 0.645
#
# 89/100 -> Questa etichetta è stata predetta 89 volte su 100.

# %% [markdown]
# # Label: City

# %%
url='http://localhost:8123/?query=SELECT top 100 iiriirrliiirliirillri  FROM extracted_data.f57978e4a01748598d876bdcc0ba1d14'

try:
    r = requests.get(url)
except ConnectionError:
        print("Il collegamento al database non è attivo.")

        
#L'utf-8-sig è una variante Python di UTF-8 che ci permette di eliminare, se presenti, eventuali carattere UTF-8 BOM.
values= r.content.decode('utf-8-sig')


#Controllo i parametri inseriti dall'utente
if (values[6:8]=='60'):
    print("ATTENZIONE! La tabella indicata non esiste.")
elif (values[6:8]=='47'):
    print("ATTENZIONE! La colonna indicata non esiste.")
else:
    print("I dati sono stati caricati correttamente.")
# Out:
# I dati sono stati caricati correttamente.

# %%
#Preprocessing
values = values.replace("\ufeff", "")
values = values.replace("\\", " ")
values=values.split('\n')
values= list(filter(lambda a: a!= '', values))
items_number= len(values)
values
# Out:
# ['Tifton, GA 31794-2693',
#  'Bloomington, MN 55425',
#  'Lake Worth, FL 33463-2113',
#  'Harrisburg, PA 17112-1012',
#  'Hollywood, CA 90028-5218',
#  '1 South Avenue',
#  'Adrian, MI 49221',
#  'Atlanta/Decatur, GA 30030-3797',
#  'Des Moines, IA 50321-9989',
#  'Aiken, SC 29802',
#  'Dallas, TX 75232',
#  'Grand Prairie, TX 75050',
#  'Greeley, CO 80632',
#  'Cuyahoga Falls, OH 44223',
#  'Norton, OH 44203-1005',
#  'Monroeville, AL 36461-2000',
#  'Thomasville, AL 36784',
#  'Montgomery, AL 36104',
#  'Albany, GA 31705',
#  'Box 32',
#  'New Haven, CT 06511',
#  'Philippi, WV 26416',
#  'Alexandria, MN 56308-2796',
#  'One Saxon Drive',
#  'Baltimore, MD 21224',
#  'Santa Maria, CA 93454-6399',
#  'Everett, PA 15537',
#  'Somerset, PA 15501',
#  'Iola, KS 66749',
#  'Alma, MI 48801-1599',
#  'Jesup, GA 31545',
#  'Hollywood, CA 90028',
#  'New York, NY 10011',
#  'Lubbock, TX 79411',
#  'Aurora, CO 80012',
#  'Youngsville, NC 27596',
#  'Boise, ID 83704',
#  'Phoenix, AZ 85043-4729',
#  'Springfield, MA 01109-3184',
#  'Bel Air, CA 90077',
#  'Shreveport, LA 71105-5646',
#  'Indianapolis, IN 46241-1445',
#  'Donaldson, IN 46513',
#  'Anderson, SC 29621',
#  'Anderson, IN 46012',
#  'Portland, ME 04103',
#  'Lufkin, TX 75902',
#  'Anoka, MN 55303',
#  'Coon Rapids, MN 55433',
#  'Jackson, MS 39208',
#  'Cincinnati, OH 45202-2592',
#  'Erdenheim, PA 19038',
#  'New York, NY 10011-2030',
#  'Portland, OR 97266',
#  'ASU Box 32004',
#  'Arlington, VA 22209',
#  'Littleton, CO 80160',
#  'Glenside, PA 19038',
#  'Mesa, AZ 85204',
#  'Phoenix, AZ 85033',
#  'PO Box 870112',
#  'Phoenix, AZ 85069-7100',
#  'Yuma, AZ 85366-0929',
#  'State University, AR 72467',
#  'Beebe, AR 72012-1008',
#  'Newport, AR 72112',
#  'Charlotte, NC 28217',
#  'Denver, CO 80203',
#  'laguna beach, ca 92651',
#  'Wilmore, KY 40390',
#  'Ashland, KY 41101-3683',
#  'Ashland, KY 41102-9046',
#  'Enfield, CT 06082',
#  'Tempe, AZ 85287-4906',
#  'Athens, GA 30601-1500',
#  'Hurst, TX 76053-7396',
#  'Miami, FL 33169-5745',
#  'Norcross, GA 30071',
#  'Atlanta, GA 30338-5820',
#  'Mays Landing, NJ 08330',
#  'Coconut Creek, FL 33063',
#  'Auburn, AL 36849-5149',
#  'Montgomery, AL 36124-4023',
#  'New York, NY 10013',
#  'Minneapolis, MN 55454',
#  'Rock Island, IL 61201-2296',
#  'Sherman, TX 75090-4400',
#  'Austin, TX 78752-4390',
#  'Exton, PA 19341-1310',
#  'Kansas City, MO 64145-1698',
#  'Kansas City, MO 64145-1698',
#  'Azusa, CA 91702-7000',
#  'Babson Park, MA 02457',
#  'Babson Park (Wellesley), MA 02457-0310',
#  'Muskogee, OK 74403',
#  'Bakersfield, CA 93305-1299',
#  'Berea, OH 44017',
#  '2000 University Avenue']

# %%
#Struttura: dictionary[label] -> [89%, 93%, 97%, 32%, 99% , ...]
dictionary={}

#Sruttura ausiliaria: permette di stabilire il numero di volte in cui ciascuna etichetta è stata predetta
occorrenze={}


#Crea una lista vuota per ciascuna label
for label in labels:
    dictionary[label]=[]
    occorrenze[label]=0
    

classifier = pipeline("zero-shot-classification")
    
labels_number= len(labels)

#Vengono effettuate le previsioni attraverso il modello.
#Le previsioni vengono memorizzate nel dizionario.
for i in range(items_number):
    text = values[i]
    result=classifier(text, labels)
    occorrenze[result['labels'][0]]+=1
    for y in range(labels_number):
        label= result['labels'][y]
        score= result['scores'][y]
        dictionary[label].append(score)    
        
        
risultati={}
for label in labels:
    risultati[label]= sum(dictionary[label])/items_number

max_score= 0

for label, score in risultati.items():  
    if score > max_score:
        label_predict=label
        max_score=score

print("Etichetta predetta: %s \n\n\n" % label_predict)
print("Grado di affidabilità: %.3f\n" % max_score)
print("%d/%d -> Questa etichetta è stata predetta %d volte su %d." 
      % (occorrenze[label_predict], items_number, occorrenze[label_predict], items_number))
# Out:
# Etichetta predetta: city
#
#
#
# Grado di affidabilità: 0.561
#
# 87/98 -> Questa etichetta è stata predetta 87 volte su 98.

# %% [markdown]
# # Label: Student Degree

# %%
url='http://localhost:8123/?query=SELECT top 100 iiriirrliiirliirrrlliirrrli  FROM extracted_data.f57978e4a01748598d876bdcc0ba1d14'

try:
    r = requests.get(url)
except ConnectionError:
        print("Il collegamento al database non è attivo.")

        
#L'utf-8-sig è una variante Python di UTF-8 che ci permette di eliminare, se presenti, eventuali carattere UTF-8 BOM.
values= r.content.decode('utf-8-sig')


#Controllo i parametri inseriti dall'utente
if (values[6:8]=='60'):
    print("ATTENZIONE! La tabella indicata non esiste.")
elif (values[6:8]=='47'):
    print("ATTENZIONE! La colonna indicata non esiste.")
else:
    print("I dati sono stati caricati correttamente.")
# Out:
# I dati sono stati caricati correttamente.

# %%
values = values.replace("\ufeff", "")
values = values.replace("\\", " ")
values=values.split('\n')
values= list(filter(lambda a: a!= '', values))
items_number= len(values)
values
# Out:
# ['Associate',
#  'Associate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Associate',
#  'Associate',
#  "Bachelor 's",
#  'Associate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Associate',
#  'Certificate',
#  'Certificate',
#  'Associate',
#  'Not Reported',
#  "Bachelor 's",
#  "Bachelor 's",
#  "Bachelor 's",
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  "Bachelor 's",
#  'Certificate',
#  'Certificate',
#  'Associate',
#  'Associate',
#  'Associate',
#  "Bachelor 's",
#  'Certificate',
#  'Not Reported',
#  'Certificate',
#  'Not Reported',
#  'Certificate',
#  'Associate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  "Bachelor 's",
#  'Certificate',
#  'Certificate',
#  'Associate',
#  "Bachelor 's",
#  'Associate',
#  'Associate',
#  'Diploma',
#  'Associate',
#  'Certificate',
#  'Associate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Not Reported',
#  'Certificate',
#  'Certificate',
#  'Associate',
#  "Bachelor 's",
#  'Associate',
#  'Not Reported',
#  "Bachelor 's",
#  "Bachelor 's",
#  'Associate',
#  'Certificate',
#  'Associate',
#  'Associate',
#  'Associate',
#  'Certificate',
#  'Certificate',
#  "Bachelor 's",
#  'Associate',
#  'Certificate',
#  'Associate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  'Certificate',
#  "Bachelor 's",
#  "Bachelor 's",
#  'Certificate',
#  'Certificate',
#  "Bachelor 's",
#  "Bachelor 's",
#  'Associate',
#  'Certificate',
#  'Certificate',
#  "Bachelor 's",
#  "Bachelor 's",
#  'Associate',
#  'Certificate',
#  "Bachelor 's",
#  'Associate']

# %%
#Struttura: dictionary[label] -> [89%, 93%, 97%, 32%, 99% , ...]
dictionary={}

#Sruttura ausiliaria: permette di stabilire il numero di volte in cui ciascuna etichetta è stata predetta
occorrenze={}


#Crea una lista vuota per ciascuna label
for label in labels:
    dictionary[label]=[]
    occorrenze[label]=0
    

classifier = pipeline("zero-shot-classification")
    
labels_number= len(labels)

#Vengono effettuate le previsioni attraverso il modello.
#Le previsioni vengono memorizzate nel dizionario.
for i in range(items_number):
    text = values[i]
    result=classifier(text, labels)
    occorrenze[result['labels'][0]]+=1
    for y in range(labels_number):
        label= result['labels'][y]
        score= result['scores'][y]
        dictionary[label].append(score)    
        
        
risultati={}
for label in labels:
    risultati[label]= sum(dictionary[label])/items_number

max_score= 0

for label, score in risultati.items():  
    if score > max_score:
        label_predict=label
        max_score=score

print("Etichetta predetta: %s \n\n\n" % label_predict)
print("Grado di affidabilità: %.3f\n" % max_score)
print("%d/%d -> Questa etichetta è stata predetta %d volte su %d." 
      % (occorrenze[label_predict], items_number, occorrenze[label_predict], items_number))
# Out:
# Etichetta predetta: student degree
#
#
#
# Grado di affidabilità: 0.528
#
# 47/97 -> Questa etichetta è stata predetta 47 volte su 97.
